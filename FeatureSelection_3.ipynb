# %%
#import libraries
import pandas as pd #pandas class
import numpy as np
import traceback
import os
import copy
import math
import statistics
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.impute import KNNImputer
import category_encoders as ce
import time
from scipy.stats import chi2_contingency
from scipy.stats import boxcox
from sklearn.ensemble import BaggingClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.inspection import permutation_importance
import logging
plt.style.use('_mpl-gallery')

# %%
try:
        
        filepath=f'/Users/chiragshah/Downloads/Projects/Data Science/home-credit-default-risk/Cleaning_3.csv'
        df=pd.read_csv(filepath)
        df.drop(columns='Unnamed: 0',inplace=True)
        #take backup of file
        backup=copy.deepcopy(df)
        
except Exception as ex:
    print(f'Following exception:\n {ex}')
    traceback.print_exc()

# %%
df.shape
# Out:
# (307511, 158)

# %%
'''There are 157 predictors currently. We'll check if all those features are required or not.
    The goal is to identify subset of features (top 25 or 50) that will yield global optimum.
    Also, can we identify the relationship (or importance) of each predictor to our model.
'''

# %%
'''Firstly, we'll select all the features and use few tree-based models.

'''

# %%
'''Separate target from predictors.'''
X=df.iloc[:,1:]
y=df.iloc[:,0]

# %%
#Split the training data in train, cross validation

X_train,X_val,y_train,y_val=train_test_split(X,y,test_size=0.30,random_state=42)

# %%
'''Grading boosing classifier.'''
n_estimators=[75,100,250,300,350]
learning_rate=[0.10,0.25,0.50,0.75,1,1.25,1.50,1.75]
def xgboost_model():
    '''XGBoost model to fit and score various'''
    
    for l_rate in learning_rate:
        xgboost=GradientBoostingClassifier(n_estimators=100,learning_rate=l_rate,max_depth=1.0,random_state=0).fit(X_train,y_train)
        score=xgboost.score(X_val,y_val)
        print('The accuracy score with {} learning rate is {}'.format(l_rate,score))

# %%
xgboost_model()
# Out:
# The accuracy score with 0.1 learning rate is 0.9196999588093742
# The accuracy score with 0.25 learning rate is 0.9196240813406464
# The accuracy score with 0.5 learning rate is 0.9198842326619984
# The accuracy score with 0.75 learning rate is 0.9198408741084397
# The accuracy score with 1 learning rate is 0.9195915624254775
# The accuracy score with 1.25 learning rate is 0.9196024020638671
# The accuracy score with 1.5 learning rate is 0.9196566002558154
# The accuracy score with 1.75 learning rate is 0.919027901229215

# %%
'''Increasing/decreasing the number of estimators is not increasing the accuracy above 0.9195915624254775.'''
'''Increasing/decreasing the learnig rate is also not increasing the accuracy above 0.9198842326619984.'''

# %%
'''Random Forest classifier.'''
#n_estimators=[75,100,125,150,175,200,225,250,300,350,500,1000,2000]
n_estimators=[100]
criterion=['gini','entropy']
def randomforest_model():
    '''Random forest model to fit and score various'''
    
    for estimator in n_estimators:
        
        for criteria in criterion:
            random_forest=RandomForestClassifier(n_estimators=estimator,criterion=criteria,random_state=0).fit(X_train,y_train)
            score=random_forest.score(X_val,y_val)
            print('The accuracy score with {} estimator and {} criteria is {}'.format(estimator,criteria,score))

# %%
randomforest_model()

# %%
'''End of the stable version of project.
    After this cell the projects

'''

# %%
df.sample(frac=0.60,axis=1)
# Out:
#         REGION_RATING_CLIENT  ORGANIZATION_TYPE_col_6  REG_CITY_NOT_WORK_CITY  \
# 0                          2                        0                       0
# 1                          1                        0                       0
# 2                          2                        0                       0
# 3                          2                        0                       0
# 4                          2                        0                       1
# ...                      ...                      ...                     ...
# 307506                     1                        0                       0
# 307507                     2                        0                       0
# 307508                     3                        0                       1
# 307509                     2                        0                       1
# 307510                     1                        0                       1
#
# ...

# %%
#XGBoost with recursive feature elimination method (greedy recursive approach).
#Genetic algorithms and simulated annealing.
# Out:
# 29765     1
# 17967     1
# 236052    1
# 113757    1
# 250544    1
#          ..
# 284206    1
# 243759    1
# 172622    1
# 244652    1
# 211076    1
# Name: TARGET, Length: 7413, dtype: int64

# %%
'''XGBoost with recursive feature elimination.
'''
def compute_score(model):
    '''Function to compute test and validation accuracy'''
    
    train_score=model.score(X_train,y_train)
    val_score=model.score(X_val,y_val)
    print('Train accuracy achieved is {}'.format(train_score))
    print('Validation accuracy achieved is {}'.format(val_score))


def recursive_feature_selection():
    '''The function will employ a feature selection technique names RFE to identify minimun subset of features that can achieve
        our objective and make prediction with acceptable accuracy.
    '''
    
    #declare variables
    assessment_sheet={}
    sampling_count=10
    
    #random sampling procedure
    sampled_df=df.sample(frac=0.50,axis=1)
    
    #separate target from predictors
    X=df.iloc[:,1:]
    y=df.iloc[:,0]
    
    #Split the data in train, cross validation.
    X_train,X_val,y_train,y_val=train_test_split(X,y,test_size=0.30,random_state=42)
    
    #XGBoost model
    xgboost=GradientBoostingClassifier(n_estimators=100,learning_rate=l_rate,max_depth=1.0,random_state=0).fit(X_train,y_train)
    
    #compute mean accuracy score
    compute_score(xgboost)
    
    #compute permuation importance

# %%
'''Grading boosing classifier.'''
n_estimators=[75,100,250,300,350]
learning_rate=[0.50]
features=[]
def xgboost_model():
    '''XGBoost model to fit and score various'''
    global features
    for l_rate in learning_rate:
        xgboost=GradientBoostingClassifier(n_estimators=100,learning_rate=l_rate,max_depth=1.0,random_state=0).fit(X_train,y_train)
        score=xgboost.score(X_val,y_val)
        
        result=permutation_importance(xgboost,X_val,y_val,n_repeats=10,n_jobs=2,random_state=42)
        print(result)

        print('The accuracy score with {} learning rate is {}'.format(l_rate,score))

# %%
xgboost_model()
# Out:
# {'importances_mean': array([ 0.00000000e+00,  0.00000000e+00,  6.07019750e-05,  1.35495480e-04,
#         0.00000000e+00,  2.70990960e-04,  0.00000000e+00,  2.05953129e-05,
#         4.22745897e-05,  3.46868428e-05,  0.00000000e+00,  0.00000000e+00,
#         1.73434214e-05,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  5.20302643e-05,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  6.82897219e-05,
#         0.00000000e+00,  0.00000000e+00,  2.07037093e-04,  5.01875257e-04,
#         6.22195244e-04,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         1.33327552e-04,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
# ...

# %%
#features[features>0.0]
df
# Out:
#         TARGET  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# 0            1             0          0.321938    0.489168     0.537543
# 1            0             0          0.362048    0.746353     0.610134
# 2            0             0          0.158484    0.244146     0.281841
# 3            0             0          0.263550    0.430802     0.573785
# 4            0             0          0.248013    0.540826     0.513513
# ...        ...           ...               ...         ...          ...
# 307506       0             0          0.286008    0.385222     0.559120
# 307507       0             0          0.168555    0.397815     0.395274
# 307508       0             0          0.281810    0.602690     0.575717
# 307509       1             0          0.297858    0.468271     0.497946
# 307510       0             0          0.286008    0.601814     0.673032
#
#         REGION_POPULATION_RELATIVE  DAYS_BIRTH  DAYS_EMPLOYED  \
# ...
